# %% [markdown]
# <a href="https://colab.research.google.com/github/jayac251/Machine_Learning/blob/main/Dataframe_Filter_isnull()_and_notnull().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# mounting google drive
from google.colab import drive
drive.mount("/gdrive")

df = pd.read_csv("/gdrive/My Drive/Colab Notebooks/employees.csv")
df.head()
# Out:
# Mounted at /gdrive
#   First Name  Gender Start Date  ... Bonus %  Senior Management             Team
# 0    Douglas    Male   8/6/1993  ...   6.945               True        Marketing
# 1     Thomas    Male  3/31/1996  ...   4.170               True              NaN
# 2      Maria  Female  4/23/1993  ...  11.858              False          Finance
# 3      Jerry    Male   3/4/2005  ...   9.340               True          Finance
# 4      Larry    Male  1/24/1998  ...   1.389               True  Client Services
#
# [5 rows x 8 columns]

# %% [markdown]
# #**Data Cleansing**

# %%
#Convert Start date, Last login time to date time object

df['Start Date'] = pd.to_datetime(df['Start Date'])

df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])




# Convert Sr.mgmt to Boolean object

df['Senior Management'] = df['Senior Management'].astype('bool')




#Convert Gender to category object
df['Gender'] = df['Gender'].astype('category')

# %% [markdown]
#  # 1. Extract the rows from the DataFrame where the value in my Team column is null

# %%
filter = df['Team'].isnull()

df[filter]
# Out:
#       First Name  Gender Start Date  ... Bonus %  Senior Management  Team
# 1         Thomas    Male 1996-03-31  ...   4.170               True   NaN
# 10        Louise  Female 1980-08-12  ...  15.132               True   NaN
# 23           NaN    Male 2012-06-14  ...   5.042               True   NaN
# 32           NaN    Male 1998-08-21  ...   6.417               True   NaN
# 91         James     NaN 2005-01-26  ...   8.309              False   NaN
# 109  Christopher    Male 2000-04-22  ...  11.449              False   NaN
# 139          NaN  Female 1990-10-03  ...  10.527               True   NaN
# 199     Jonathan    Male 2009-07-17  ...  16.736               True   NaN
# 258      Michael    Male 2002-01-24  ...  12.659              False   NaN
# 290       Jeremy    Male 1988-06-14  ...  13.657               True   NaN
# 314        Bobby    Male 1996-03-31  ...   6.338              False   NaN
# 367       Edward    Male 1989-08-04  ...  10.957               True   NaN
# ...

# %% [markdown]
# # 2.Extract all the rows from our df DataFrame where the value in the Gender column is not null

# %%
filter = df['Gender'].notnull()

df[filter]
# Out:
#     First Name  Gender  ... Senior Management                  Team
# 0      Douglas    Male  ...              True             Marketing
# 1       Thomas    Male  ...              True                   NaN
# 2        Maria  Female  ...             False               Finance
# 3        Jerry    Male  ...              True               Finance
# 4        Larry    Male  ...              True       Client Services
# ..         ...     ...  ...               ...                   ...
# 994     George    Male  ...              True             Marketing
# 996    Phillip    Male  ...             False               Finance
# 997    Russell    Male  ...             False               Product
# 998      Larry    Male  ...             False  Business Development
# 999     Albert    Male  ...              True                 Sales
#
# [855 rows x 8 columns]
