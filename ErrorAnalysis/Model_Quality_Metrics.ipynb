# %% [markdown]
# <a href="https://colab.research.google.com/github/jayac251/Machine_Learning/blob/main/Model_Quality_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

period = ['Jan','Feb','Mar','Apr',
          'May','Jun','Jul','Aug',
          'Sep','Oct','Nov','Dec']


actual = [35,35,10,5,
          8,10,15,20,
          23,21,22,25]

forecast = [30,31,30,
           10,12,17,
           18,27,29,
           24,23,22]          

data = pd.DataFrame({'period' : period,
                     'actual': actual,
                     'forecast': forecast})

ax = data.plot.line(x = 'period')
ax.set_title('Forecast vs Actual', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#MSE

from sklearn.metrics import mean_squared_error
print(mean_squared_error(data['actual'],data['forecast']))

# smaller the error better the model
# Out:
# 53.666666666666664

# %%
#RMSE
from math import sqrt


print(sqrt(mean_squared_error(data['actual'],data['forecast'])))

# lower RMSE better the model
# Out:
# 7.32575365861197

# %%
#MAE
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(data['actual'],data['forecast']))
# Out:
# 5.666666666666667

# %%
#MAPE
from sklearn.metrics import mean_absolute_percentage_error

print(mean_absolute_percentage_error(data['actual'],data['forecast']))

# results in % metric
# Out:
# 0.46469367588932814

# %%
#R2
from sklearn.metrics import r2_score
print(r2_score(data['actual'],data['forecast']))

# % of increase of your model than the average
# measured on a scale of 0 to 1, the above data means 40% BETTER PERFORMANCE THAN THE AVERAGE.
# if the model is as bad  a pediction asusing the average, then the R2 will be zero.
# THe only case where R2 can be negative is when the forecast is more than 100% wrong
# Out:
# 0.39976699029126206

# %%
print('MSE:', mean_squared_error(data['actual'],data['forecast']))
print('RMSE:', sqrt(mean_squared_error(data['actual'],data['forecast'])))
print('MAE:',mean_absolute_error(data['actual'],data['forecast']))
print('MAPE:', mean_absolute_percentage_error(data['actual'],data['forecast']))
print('R2:',r2_score(data['actual'],data['forecast']))
# Out:
# MSE: 53.666666666666664
# RMSE: 7.32575365861197
# MAE: 5.666666666666667
# MAPE: 0.46469367588932814
# R2: 0.39976699029126206

# %%
actual = [35,35,10,5,
          8,10,15,20,
          23,21,22,25]

forecast = [35,35,10,5,
          8,10,15,20,
          23,21,22,25] 

data = pd.DataFrame({'period' : period,
                     'actual': actual,
                     'forecast': forecast})

ax = data.plot.line(x = 'period')
ax.set_title('Forecast vs Actual', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show

print('MSE:', mean_squared_error(data['actual'],data['forecast']))
print('RMSE:', sqrt(mean_squared_error(data['actual'],data['forecast'])))
print('MAE:',mean_absolute_error(data['actual'],data['forecast']))
print('MAPE:', mean_absolute_percentage_error(data['actual'],data['forecast']))
print('R2:',r2_score(data['actual'],data['forecast']))
# Out:
# MSE: 0.0
# RMSE: 0.0
# MAE: 0.0
# MAPE: 0.0
# R2: 1.0

# %%
forecast = [6,3,1,5,
          3,1,5,2,
          6,4,22,5] 

data = pd.DataFrame({'period' : period,
                     'actual': actual,
                     'forecast': forecast})
ax = data.plot.line(x = 'period')
ax.set_title('Forecast vs Actual', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show

print('MSE:', mean_squared_error(data['actual'],data['forecast']))
print('RMSE:', sqrt(mean_squared_error(data['actual'],data['forecast'])))
print('MAE:',mean_absolute_error(data['actual'],data['forecast']))
print('MAPE:', mean_absolute_percentage_error(data['actual'],data['forecast']))
print('R2:',r2_score(data['actual'],data['forecast']))
# Out:
# MSE: 287.8333333333333
# RMSE: 16.96565157408737
# MAE: 13.833333333333334
# MAPE: 0.673598171152519
# R2: -2.2192621359223303

# %%
forecast = [30,32,10,5,
          8,10,15,30,
          20,15,22,35]

data = pd.DataFrame({'period' : period,
                     'actual': actual,
                     'forecast': forecast})

ax = data.plot.line(x = 'period')
ax.set_title('Forecast vs Actual', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show

print('MSE:', mean_squared_error(data['actual'],data['forecast']))
print('RMSE:', sqrt(mean_squared_error(data['actual'],data['forecast'])))
print('MAE:',mean_absolute_error(data['actual'],data['forecast']))
print('MAPE:', mean_absolute_percentage_error(data['actual'],data['forecast']))
print('R2:',r2_score(data['actual'],data['forecast']))
# Out:
# MSE: 23.25
# RMSE: 4.8218253804964775
# MAE: 3.0833333333333335
# MAPE: 0.12872670807453415
# R2: 0.7399611650485436
